# %% [markdown]
# <a href="https://colab.research.google.com/github/aditiR2508/Basics-of-Python/blob/main/expt1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aditi Rathore
# ## 25070123006
# ## Batch 2025-29
# ## EDA using Python
# ## Expt-1
# ## Python Basics

# %%
# First Python program
print("I am aditi :)")
# Out:
# I am aditi :)

# %%
print("jack of all trades but master of none")
# Out:
# jack of all trades but master of none

# %%
a = "hi"
print(a)
# Out:
# hi

# %%
print("The Metamorphosis"); print("Franz Kafka"); print("Russian Writer")
# Out:
# The Metamorphosis
# Franz Kafka
# Russian Writer

# %%
print("I am aditi.", end=" ")
print("My bday is closeeeeee")
# Out:
# I am aditi. My bday is closeeeeee

# %%
#NUMBERS
a=6769
print(a)
print(1729)
# Out:
# 6769
# 1729

# %%
#VARIABLES
x=89
y="hehhehhehheheh"
print(x)
print(y)
# Out:
# 89
# hehhehhehheheh

# %%
#case sensitive
a=6334
A=5412
print(a)
print(A)
# Out:
# 6334
# 5412

# %%
#Many values to multiple variables
p, q, r= "haha", "hehe", "hihi"

print(p)
print(q)
print(r)
# Out:
# haha
# hehe
# hihi

# %%
#basic arithmetic operations
a=7
b=25
print("Addition=", a+b); print("Subtraction=", a-b); print("Multiplication=", a*b); print("Division=", a/b)
# Out:
# Addition= 32
# Subtraction= -18
# Multiplication= 175
# Division= 0.28

# %%
#Understanding Data Types
x=10
y=7.29
z="duck"
minion= True #do not write small t or it shows error
p=5+7j

print(type(x))
print(type(y))
print(type(z))
print(type(minion))
print(type(p))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'complex'>

# %%
name= input("Enter your name: ") #taking user input
age= int(input("Enter age: "))

print("eylo", name)
print("my age is", age)
# Out:
# Enter your name: aditi
# Enter age: 17
# eylo aditi
# my age is 17

# %%
#Simple Calculator
x= int(input("Enter first no.: "))
y= int(input("Enter second no.: "))
print(x)
print(y)

print("Addition=", x+y)
print("Subtraction=", x-y)
print("Multiplication=", x*y)
print("Division=",x/y)
# Out:
# Enter first no.: 5
# Enter second no.: 10
# 5
# 10
# Addition= 15
# Subtraction= -5
# Multiplication= 50
# Division= 0.5

# %%
#subject marks
print("marks of the 5 subjects: ")
a= int(input(" "))
b= int(input(" "))
c= int(input(" "))
d= int(input(" "))
e= int(input(" "))

f= a+b+c+d+e
print("Total marks=", f)
print("avg=", f/5)
# Out:
# marks of the 5 subjects:
#  34
#  45
#  56
#  52
#  49
# Total marks= 236
# avg= 47.2

# %%
#area of rectangle and circle
l= int(input("Enter length: "))
b= int(input("Enter breadth: "))
r= float(input("Enter radius: "))
pi=3.14
print("area of rectangle=", l*b)
print("area of circle=", pi*r*r)
# Out:
# Enter length: 10
# Enter breadth: 20
# Enter radius: 2
# area of rectangle= 200
# area of circle= 12.56

# %%
#double stars-->exponent
a=3*3
b=3**3

print(a)
print(b)
# Out:
# 9
# 27

# %%
#tuple joining or appending
print((3, 4, 5)+ (6, 7, 8))
# Out:
# (3, 4, 5, 6, 7, 8)
